# %%
# Import necessary libraries
import pandas as pd 
import requests
import os
# %pip install openai
from openai import OpenAI
import json
# %pip install SQLAlchemy
# %pip install mysqlclient
from sqlalchemy import create_engine
# Out:
# Requirement already satisfied: openai in /usr/local/python/3.10.13/lib/python3.10/site-packages (1.23.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: SQLAlchemy in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.0.29)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.local/lib/python3.10/site-packages (from SQLAlchemy) (4.10.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/python/3.10.13/lib/python3.10/site-packages (from SQLAlchemy) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mysqlclient in /usr/local/python/3.10.13/lib/python3.10/site-packages (2.2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Set the API key from secrets
openai_api_key = os.getenv('OPENAI_API_KEY')

# %%
client = OpenAI(api_key=openai_api_key)

# %%
# Read the CSV data
data = pd.read_csv('eu_countries.csv')

# List to store responses
responses1 = []

# Iterate over the country values
for country in data['eu_country']:
    response = client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=f"What is the capital city of {country}?",
        max_tokens=100
    )
    # Append the response text to the list
    responses1.append(response.choices[0].text)

# %%
responses1
# Out:
# ['\nThe capital city of Austria is Vienna.',
#  '\n\nThe capital city of Belgium is Brussels. ',
#  '\n\nThe capital city of Bulgaria is Sofia.',
#  '\nThe capital city of Croatia is Zagreb.',
#  '\n\nThe capital city of Cyprus is Nicosia.',
#  '\n\nThe capital city of Czech Republic is Prague.',
#  '\n\nThe capital city of Denmark is Copenhagen.',
#  '\n\nThe capital city of Estonia is Tallinn.',
#  '\n\nThe capital city of Finland is Helsinki.',
#  '\n\nThe capital city of France is Paris.',
#  '\n\nThe capital city of Germany is Berlin.',
#  '\n\nThe capital city of Greece is Athens. It is also the largest city in the country.',
#  '\n\nBudapest is the capital city of Hungary.',
#  '\n\nThe capital city of Ireland is Dublin.',
#  '\n\nThe capital city of Italy is Rome.',
#  '\n\nThe capital city of Latvia is Riga.',
#  '\n\nThe capital city of Lithuania is Vilnius.',
#  '\n\nThe capital city of Luxembourg is Luxembourg City.',
#  '\n\nValletta ',
#  '\n\nThe capital city of the Netherlands is Amsterdam.',
#  '\n\nThe capital city of Poland is Warsaw. ',
#  '\n\nThe capital city of Portugal is Lisbon.',
#  '\n\nThe capital city of Romania is Bucharest.',
#  '\n\nThe capital city of Slovakia is Bratislava. ',
#  '\n\nThe capital city of Slovenia is Ljubljana.',
#  '\n\nMadrid is the capital city of Spain.',
#  '\n\nThe capital city of Sweden is Stockholm.']

# %%
# List to store responses
responses2 = []

# Iterate over the capital city values
for city in responses1:
    response = client.completions.create(
        model="gpt-3.5-turbo-instruct",
        prompt=f"What is the UN/LOCODE (United Nations Code for Trade and Transport Locations) of {city}?",
        max_tokens=100
    )
    # Append the response text to the list
    responses2.append(response.choices[0].text)

# %%
responses2
# Out:
# ['\n\nThe UN/LOCODE for Vienna, Austria is AT VIE.',
#  '\n\nThe UN/LOCODE for Brussels is BE BRU.',
#  '\n\nThe UN/LOCODE for Sofia, Bulgaria is BGSOF.',
#  '\n\nThe UN/LOCODE for Zagreb, Croatia is HR ZAG.',
#  '\n\nCY NIC',
#  '\n\nThe UN/LOCODE for Prague is CZ PRG.',
#  '\n\nThe UN/LOCODE for Copenhagen, Denmark is DK CPH.',
#  '\n\nThe UN/LOCODE for Tallinn, Estonia is EETLL. ',
#  '\n\nThe UN/LOCODE for Helsinki, Finland is FI HEL. ',
#  '\n\nThe UN/LOCODE for Paris, France is FR PAR.',
#  '\n\nThe UN/LOCODE for Berlin, Germany is DE BER.',
#  '\n\nThe UN/LOCODE for Athens, Greece is GRCPT.',
#  '\n\nHU BUD ',
#  '\n\nThe UN/LOCODE for Dublin, Ireland is IE DUB.',
#  '\n\nThe UN/LOCODE for Rome, Italy is IT ROM.',
#  '\n\nThe UN/LOCODE for Riga, Latvia is LV RIX.',
#  '\n\nThe UN/LOCODE for Vilnius, Lithuania is LT VNO.',
#  '\n\nThe UN/LOCODE for Luxembourg City is LULUX.',
#  '\n\nMT MLA ',
#  '\n\nThe UN/LOCODE for Amsterdam is NL AMS.',
#  '\n\nThe UN/LOCODE for Warsaw, Poland is PLWAW.',
#  '\n\nThe UN/LOCODE for Lisbon, Portugal is PT LIS.',
#  '\n\nThe UN/LOCODE for Bucharest, Romania is ROBUH.',
#  '\n\nThe UN/LOCODE for Bratislava, Slovakia is SK BTS.',
#  '\n\nSI LJU',
#  '\n\nThe UN/LOCODE for Madrid is ES MAD.',
#  '\n\nThe UN/LOCODE for Stockholm, Sweden is SE STO. ']

# %%
df = pd.DataFrame({'EU_Country': data['eu_country'], 'Capital_City': responses1, 'UN_Location_Code' : responses2})

# %%
df
# Out:
#          EU_Country                                       Capital_City  \
# 0           Austria           \nThe capital city of Austria is Vienna.
# 1           Belgium      \n\nThe capital city of Belgium is Brussels.
# 2          Bulgaria         \n\nThe capital city of Bulgaria is Sofia.
# 3           Croatia           \nThe capital city of Croatia is Zagreb.
# 4            Cyprus         \n\nThe capital city of Cyprus is Nicosia.
# 5    Czech Republic  \n\nThe capital city of Czech Republic is Prague.
# 6           Denmark     \n\nThe capital city of Denmark is Copenhagen.
# 7           Estonia        \n\nThe capital city of Estonia is Tallinn.
# 8           Finland       \n\nThe capital city of Finland is Helsinki.
# 9            France           \n\nThe capital city of France is Paris.
# 10          Germany         \n\nThe capital city of Germany is Berlin.
# 11           Greece  \n\nThe capital city of Greece is Athens. It i...
# 12          Hungary       \n\nBudapest is the capital city of Hungary.
# 13          Ireland         \n\nThe capital city of Ireland is Dublin.
# 14            Italy             \n\nThe capital city of Italy is Rome.
# 15           Latvia            \n\nThe capital city of Latvia is Riga.
# 16        Lithuania      \n\nThe capital city of Lithuania is Vilnius.
# 17       Luxembourg  \n\nThe capital city of Luxembourg is Luxembou...
# 18            Malta                                      \n\nValletta
# 19  the Netherlands  \n\nThe capital city of the Netherlands is Ams...
# 20           Poland         \n\nThe capital city of Poland is Warsaw.
# 21         Portugal        \n\nThe capital city of Portugal is Lisbon.
# 22          Romania      \n\nThe capital city of Romania is Bucharest.
# 23         Slovakia   \n\nThe capital city of Slovakia is Bratislava.
# 24         Slovenia     \n\nThe capital city of Slovenia is Ljubljana.
# 25            Spain           \n\nMadrid is the capital city of Spain.
# 26           Sweden       \n\nThe capital city of Sweden is Stockholm.
#
#                                      UN_Location_Code
# 0    \n\nThe UN/LOCODE for Vienna, Austria is AT VIE.
# 1           \n\nThe UN/LOCODE for Brussels is BE BRU.
# 2     \n\nThe UN/LOCODE for Sofia, Bulgaria is BGSOF.
# 3    \n\nThe UN/LOCODE for Zagreb, Croatia is HR ZAG.
# 4                                          \n\nCY NIC
# 5             \n\nThe UN/LOCODE for Prague is CZ PRG.
# 6   \n\nThe UN/LOCODE for Copenhagen, Denmark is D...
# 7   \n\nThe UN/LOCODE for Tallinn, Estonia is EETLL.
# 8   \n\nThe UN/LOCODE for Helsinki, Finland is FI ...
# 9      \n\nThe UN/LOCODE for Paris, France is FR PAR.
# 10   \n\nThe UN/LOCODE for Berlin, Germany is DE BER.
# 11     \n\nThe UN/LOCODE for Athens, Greece is GRCPT.
# 12                                        \n\nHU BUD
# 13   \n\nThe UN/LOCODE for Dublin, Ireland is IE DUB.
# 14       \n\nThe UN/LOCODE for Rome, Italy is IT ROM.
# 15      \n\nThe UN/LOCODE for Riga, Latvia is LV RIX.
# 16  \n\nThe UN/LOCODE for Vilnius, Lithuania is LT...
# 17    \n\nThe UN/LOCODE for Luxembourg City is LULUX.
# 18                                        \n\nMT MLA
# 19         \n\nThe UN/LOCODE for Amsterdam is NL AMS.
# 20     \n\nThe UN/LOCODE for Warsaw, Poland is PLWAW.
# 21  \n\nThe UN/LOCODE for Lisbon, Portugal is PT LIS.
# 22  \n\nThe UN/LOCODE for Bucharest, Romania is RO...
# 23  \n\nThe UN/LOCODE for Bratislava, Slovakia is ...
# 24                                         \n\nSI LJU
# 25            \n\nThe UN/LOCODE for Madrid is ES MAD.
# 26  \n\nThe UN/LOCODE for Stockholm, Sweden is SE ...

# %%
# Save the data to a CSV file to then clean with Excel
df.to_csv('eu_countries_unlocode.csv', index=False)

# %%
# Import cleaned data from CSV file
data2 = pd.read_csv('eu_countries_unlocode_clean.csv')

# %%
data2
# Out:
#    UN_Location_Code      EU_Country     Capital_City  Region Eurozone
# 0             ATVIE         Austria           Vienna    West      Yes
# 1             BEBRU         Belgium         Brussels    West      Yes
# 2             BGSOF        Bulgaria            Sofia    East       No
# 3             HRZAG         Croatia           Zagreb   South      Yes
# 4             CZPRG  Czech Republic           Prague    East       No
# 5             DKCPH         Denmark       Copenhagen  North        No
# 6             EETLL         Estonia          Tallinn  North       Yes
# 7             FIHEL         Finland         Helsinki  North       Yes
# 8             FRPAR          France            Paris    West      Yes
# 9             DEBER         Germany          Berlin     West      Yes
# 10            GRATH          Greece           Athens   South      Yes
# 11            HUBUD         Hungary         Budapest    East       No
# 12            IEDUB         Ireland           Dublin  North       Yes
# 13            ITROM           Italy             Rome   South      Yes
# 14            LVRIX          Latvia             Riga  North       Yes
# 15            LTVNO       Lithuania          Vilnius  North       Yes
# 16            LULUX      Luxembourg  Luxembourg City    West      Yes
# 17            MTMLA           Malta         Valletta   South      Yes
# 18            NLAMS     Netherlands        Amsterdam    West      Yes
# 19            PLWAW          Poland           Warsaw    East       No
# 20           PTLIS         Portugal           Lisbon   South      Yes
# 21            ROBUH         Romania        Bucharest    East       No
# 22            SKBTS        Slovakia       Bratislava    East      Yes
# 23            SILJU        Slovenia        Ljubljana   South      Yes
# 24            ESMAD           Spain           Madrid   South      Yes
# 25            SESTO          Sweden        Stockholm  North        No

# %%
# Read data to be used on the Freightos API as the input
data2['UN_Location_Code']
# Out:
# 0      ATVIE
# 1      BEBRU
# 2      BGSOF
# 3      HRZAG
# 4      CZPRG
# 5      DKCPH
# 6      EETLL
# 7      FIHEL
# 8      FRPAR
# 9      DEBER
# 10     GRATH
# 11     HUBUD
# 12     IEDUB
# 13     ITROM
# 14     LVRIX
# 15     LTVNO
# 16     LULUX
# 17     MTMLA
# 18     NLAMS
# 19     PLWAW
# 20    PTLIS
# 21     ROBUH
# 22     SKBTS
# 23     SILJU
# 24     ESMAD
# 25     SESTO
# Name: UN_Location_Code, dtype: object

# %%
# Set the API key from secrets
api_key = os.getenv('FREIGHTOS_API_KEY')
# Endpoint URL for the Freight Rate Estimator API
url = 'https://api.freightos.com/api/v1/freightEstimates'

# Headers including the required API key
headers = {
    'Content-Type': 'application/json',
    'x-apikey': api_key
}

# request body for the Freight Rate Estimator API
# Only destination input is changed 1-by-1 
payload = {
  "load": [
    {
      "quantity": 1,
      "unitType": "boxes",
      "unitVolumeCBM": 0.1
    }
  ],
  "legs": [
    {
      "origin": {
        "unLocationCode": "USLAX",
        "airportCode": "LAX"
      },
      "destination": {
        "unLocationCode": "SESTO", 
        "airportCode": "STO"
      },
    }
  ]
}

response = requests.post(url, json=payload, headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
# Compile responses to one Excel file (1-by-1)
# CYNIC response unavailable
# FRPAR airportCode is CDG
# ITROM airportCode is FCO
# ROBUH airportCode is OTP
response.json()
# Out:
# {'AIR': {'priceEstimate': {'min': 27.27, 'max': 48.01}, 'transitTime': {}}}

# %%
# Import cleaned data from CSV files
eu_unlocodes_df = pd.read_csv('eu_countries_unlocode_clean.csv')
air_freight_price_estimate_df = pd.read_csv('air_freight_price_estimate.csv')

# %%
eu_unlocodes_df.head()
# Out:
#   UN_Location_Code      EU_Country Capital_City Region Eurozone
# 0            ATVIE         Austria       Vienna   West      Yes
# 1            BEBRU         Belgium     Brussels   West      Yes
# 2            BGSOF        Bulgaria        Sofia   East       No
# 3            HRZAG         Croatia       Zagreb  South      Yes
# 4            CZPRG  Czech Republic       Prague   East       No

# %%
air_freight_price_estimate_df.head()
# Out:
#   UN_Location_Code  Min_Price_Estimate_USD  Max_Price_Estimate_USD  \
# 0            ATVIE                   25.16                   48.97
# 1            BEBRU                   24.39                   38.79
# 2            BGSOF                   34.38                   85.46
# 3            HRZAG                   60.50                   88.92
# 4            CZPRG                   24.97                   45.71
#
#    AVG_Price_Estimate_USD
# 0                  37.065
# 1                  31.590
# 2                  59.920
# 3                  74.710
# 4                  35.340

# %%
# Create a connection to the MySQL database
engine = create_engine(f'mysql+mysqldb://admin:isba_4715@isba-dev-01.cnuo66oue0ny.us-east-1.rds.amazonaws.com/sql_project')

# %%
# Save the cleaned data to a MySQL database
eu_unlocodes_df.to_sql('eu_unlocodes', engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1971, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1970     if not evt_handled:
# -> 1971         self.dialect.do_execute(
#    1972             cursor, str_statement, effective_parameters, context
#    1973         )
#    1975 if self._has_events or self.engine._has_events:
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/default.py:919, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     918 def do_execute(self, cursor, statement, parameters, context=None):
# --> 919     cursor.execute(statement, parameters)
#
# File ~/.python/current/lib/python3.10/site-packages/MySQLdb/cursors.py:179, in BaseCursor.execute(self, query, args)
#     178 assert isinstance(mogrified_query, (bytes, bytearray))
# --> 179 res = self._query(mogrified_query)
#     180 return res
#
# File ~/.python/current/lib/python3.10/site-packages/MySQLdb/cursors.py:330, in BaseCursor._query(self, q)
#     329 self.lastrowid = None
# --> 330 db.query(q)
#     331 self._do_get_result(db)
#
# File ~/.python/current/lib/python3.10/site-packages/MySQLdb/connections.py:261, in Connection.query(self, query)
#     260     query = bytes(query)
# --> 261 _mysql.connection.query(self, query)
#
# OperationalError: (3730, "Cannot drop table 'eu_unlocodes' referenced by a foreign key constraint 'fk_unlocode' on table 'air_freight_price_estimate'.")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Save the cleaned data to a MySQL database
# ----> 2 eu_unlocodes_df.to_sql('eu_unlocodes', engine, if_exists='replace', index=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:3084, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2886 """
#    2887 Write records stored in a DataFrame to a SQL database.
#    2888
#    (...)
#    3080 [(1,), (None,), (2,)]
#    3081 """  # noqa: E501
#    3082 from pandas.io import sql
# -> 3084 return sql.to_sql(
#    3085     self,
#    3086     name,
#    3087     con,
#    3088     schema=schema,
#    3089     if_exists=if_exists,
#    3090     index=index,
#    3091     index_label=index_label,
#    3092     chunksize=chunksize,
#    3093     dtype=dtype,
#    3094     method=method,
#    3095 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:2008, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1958 """
#    1959 Write records stored in a DataFrame to a SQL database.
#    1960
#    (...)
#    2004     Any additional kwargs are passed to the engine.
#    2005 """
#    2006 sql_engine = get_engine(engine)
# -> 2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    2011     if_exists=if_exists,
#    2012     index=index,
#    2013     index_label=index_label,
#    2014     schema=schema,
#    2015     dtype=dtype,
#    2016 )
#    2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    (...)
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:1912, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1900             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1902 table = SQLTable(
#    1903     name,
#    1904     self,
#    (...)
#    1910     dtype=dtype,
#    1911 )
# -> 1912 table.create()
#    1913 return table
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:988, in SQLTable.create(self)
#     986     raise ValueError(f"Table '{self.name}' already exists.")
#     987 if self.if_exists == "replace":
# --> 988     self.pd_sql.drop_table(self.name, self.schema)
#     989     self._execute_create()
#     990 elif self.if_exists == "append":
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/sql.py:2063, in SQLDatabase.drop_table(self, table_name, schema)
#    2059 self.meta.reflect(
#    2060     bind=self.con, only=[table_name], schema=schema, views=True
#    2061 )
#    2062 with self.run_transaction():
# -> 2063     self.get_table(table_name, schema).drop(bind=self.con)
#    2064 self.meta.clear()
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/sql/schema.py:1300, in Table.drop(self, bind, checkfirst)
#    1290 def drop(self, bind: _CreateDropBind, checkfirst: bool = False) -> None:
#    1291     """Issue a ``DROP`` statement for this
#    1292     :class:`_schema.Table`, using the given
#    1293     :class:`.Connection` or :class:`.Engine` for connectivity.
#    (...)
#    1298
#    1299     """
# -> 1300     bind._run_ddl_visitor(ddl.SchemaDropper, self, checkfirst=checkfirst)
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2461, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2449 def _run_ddl_visitor(
#    2450     self,
#    2451     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    2452     element: SchemaItem,
#    2453     **kwargs: Any,
#    2454 ) -> None:
#    2455     """run a DDL visitor.
#    2456
#    2457     This method is only here so that the MockConnection can change the
#    2458     options given to the visitor so that "checkfirst" is skipped.
#    2459
#    2460     """
# -> 2461     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/sql/visitors.py:664, in ExternalTraversal.traverse_single(self, obj, **kw)
#     662 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     663 if meth:
# --> 664     return meth(obj, **kw)
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/sql/ddl.py:1143, in SchemaDropper.visit_table(self, table, drop_ok, _is_metadata_operation, _ignore_sequences)
#    1136     return
#    1138 with self.with_ddl_events(
#    1139     table,
#    1140     checkfirst=self.checkfirst,
#    1141     _is_metadata_operation=_is_metadata_operation,
#    1142 ):
# -> 1143     DropTable(table)._invoke_with(self.connection)
#    1145     # traverse client side defaults which may refer to server-side
#    1146     # sequences. noting that some of these client side defaults may
#    1147     # also be set up as server side defaults
#    (...)
#    1150     # #associating-a-sequence-as-the-server-side-
#    1151     # default), so have to be dropped after the table is dropped.
#    1152     for column in table.columns:
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/sql/ddl.py:314, in ExecutableDDLElement._invoke_with(self, bind)
#     312 def _invoke_with(self, bind):
#     313     if self._should_execute(self.target, bind):
# --> 314         return bind.execute(self)
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1422, in Connection.execute(self, statement, parameters, execution_options)
#    1420     raise exc.ObjectNotExecutableError(statement) from err
#    1421 else:
# -> 1422     return meth(
#    1423         self,
#    1424         distilled_parameters,
#    1425         execution_options or NO_OPTIONS,
#    1426     )
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/sql/ddl.py:180, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     177 def _execute_on_connection(
#     178     self, connection, distilled_params, execution_options
#     179 ):
# --> 180     return connection._execute_ddl(
#     181         self, distilled_params, execution_options
#     182     )
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1533, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1528 dialect = self.dialect
#    1530 compiled = ddl.compile(
#    1531     dialect=dialect, schema_translate_map=schema_translate_map
#    1532 )
# -> 1533 ret = self._execute_context(
#    1534     dialect,
#    1535     dialect.execution_ctx_cls._init_ddl,
#    1536     compiled,
#    1537     None,
#    1538     exec_opts,
#    1539     compiled,
#    1540 )
#    1541 if self._has_events or self.engine._has_events:
#    1542     self.dispatch.after_execute(
#    1543         self,
#    1544         ddl,
#    (...)
#    1548         ret,
#    1549     )
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1850, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1848     return self._exec_insertmany_context(dialect, context)
#    1849 else:
# -> 1850     return self._exec_single_context(
#    1851         dialect, context, statement, parameters
#    1852     )
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1990, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1987     result = context._setup_result_proxy()
#    1989 except BaseException as e:
# -> 1990     self._handle_dbapi_exception(
#    1991         e, str_statement, effective_parameters, cursor, context
#    1992     )
#    1994 return result
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2357, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2355 elif should_wrap:
#    2356     assert sqlalchemy_exception is not None
# -> 2357     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2358 else:
#    2359     assert exc_info[1] is not None
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1971, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1969                 break
#    1970     if not evt_handled:
# -> 1971         self.dialect.do_execute(
#    1972             cursor, str_statement, effective_parameters, context
#    1973         )
#    1975 if self._has_events or self.engine._has_events:
#    1976     self.dispatch.after_cursor_execute(
#    1977         self,
#    1978         cursor,
#    (...)
#    1982         context.executemany,
#    1983     )
#
# File ~/.python/current/lib/python3.10/site-packages/sqlalchemy/engine/default.py:919, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     918 def do_execute(self, cursor, statement, parameters, context=None):
# --> 919     cursor.execute(statement, parameters)
#
# File ~/.python/current/lib/python3.10/site-packages/MySQLdb/cursors.py:179, in BaseCursor.execute(self, query, args)
#     176 mogrified_query = self._mogrify(query, args)
#     178 assert isinstance(mogrified_query, (bytes, bytearray))
# --> 179 res = self._query(mogrified_query)
#     180 return res
#
# File ~/.python/current/lib/python3.10/site-packages/MySQLdb/cursors.py:330, in BaseCursor._query(self, q)
#     328 self.rowcount = None
#     329 self.lastrowid = None
# --> 330 db.query(q)
#     331 self._do_get_result(db)
#     332 self._post_get_result()
#
# File ~/.python/current/lib/python3.10/site-packages/MySQLdb/connections.py:261, in Connection.query(self, query)
#     259 if isinstance(query, bytearray):
#     260     query = bytes(query)
# --> 261 _mysql.connection.query(self, query)
#
# OperationalError: (MySQLdb.OperationalError) (3730, "Cannot drop table 'eu_unlocodes' referenced by a foreign key constraint 'fk_unlocode' on table 'air_freight_price_estimate'.")
# [SQL:
# DROP TABLE eu_unlocodes]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Save the cleaned data to a MySQL database
air_freight_price_estimate_df.to_sql('air_freight_price_estimate', engine, if_exists='replace', index=False)
# Out:
# 26
